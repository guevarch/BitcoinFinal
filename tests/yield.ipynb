# %%
import yfinance as yf
import datetime

# Define the tickers
tickers = ['BTC-USD', 'BITO']

# Fetch the data
# Fetch the data
btcy = yf.download(tickers, start='2020-01-01', end=datetime.datetime.today().strftime('%Y-%m-%d'))

# Remove NaN values
btcy = btcy.dropna()
# Keep only the Date and Close columns
btcy = btcy[['Close']]
# Display the data

# Calculate daily returns
btcy['Daily Return BITO'] = btcy[('Close', 'BITO')].pct_change()
btcy['Daily Return BTC-USD'] = btcy[('Close', 'BTC-USD')].pct_change()

# Calculate cumulative returns
btcy['Cumulative Return BITO'] = (1 + btcy['Daily Return BITO']).cumprod()
btcy['Cumulative Return BTC-USD'] = (1 + btcy['Daily Return BTC-USD']).cumprod()

# Display the data
btcy[['Cumulative Return BITO', 'Cumulative Return BTC-USD']].dropna().tail()
btcy.head()
# Out:
# c:\Users\chris\anaconda3\envs\python_data\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]c:\Users\chris\anaconda3\envs\python_data\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  2 of 2 completed
#                 Close               Daily Return BITO Daily Return BTC-USD  \
#                  BITO       BTC-USD
# Date
# 2021-10-20  43.279999  65992.835938               NaN                  NaN
# 2021-10-21  40.830002  62210.171875         -0.056608            -0.057319
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Add BITO trace
fig.add_trace(
    go.Scatter(x=btcy.index, y=btcy[('Close', 'BITO')], name='BITO', yaxis='y1')
)

# Add BTC-USD trace
fig.add_trace(
    go.Scatter(x=btcy.index, y=btcy[('Close', 'BTC-USD')], name='BTC-USD', yaxis='y2')
)

# Create axis objects
fig.update_layout(
    xaxis=dict(title='Date'),
    yaxis=dict(title='BITO', side='left'),
    yaxis2=dict(title='BTC-USD', side='right', overlaying='y')
)

fig.show()

# %%
# Define the tickers
tickers = ['MSTY', 'MSTR']

# Fetch the data
MSTY = yf.download(tickers, start='2020-01-01', end=datetime.datetime.today().strftime('%Y-%m-%d'))

# Remove NaN values
MSTY = MSTY.dropna()
# Keep only the Date and Close columns
MSTY = MSTY[['Close']]

# Calculate daily returns
MSTY['Daily Return MSTY'] = MSTY[('Close', 'MSTY')].pct_change()
MSTY['Daily Return MSTR'] = MSTY[('Close', 'MSTR')].pct_change()

# Calculate cumulative returns
MSTY['Cumulative Return MSTY'] = (1 + MSTY['Daily Return MSTY']).cumprod()
MSTY['Cumulative Return MSTR'] = (1 + MSTY['Daily Return MSTR']).cumprod()

# Display the data
MSTY[['Cumulative Return MSTY', 'Cumulative Return MSTR']].dropna().tail()
MSTY.tail()
# Out:
# c:\Users\chris\anaconda3\envs\python_data\Lib\site-packages\yfinance\utils.py:775: FutureWarning:
#
# The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#
# c:\Users\chris\anaconda3\envs\python_data\Lib\site-packages\yfinance\utils.py:775: FutureWarning:
#
# The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#
# [*********************100%%**********************]  2 of 2 completed
#                  Close            Daily Return MSTY Daily Return MSTR  \
#                   MSTR       MSTY
# Date
# 2024-12-24  358.179993  31.209999          0.063373          0.078108
# 2024-12-26  341.049988  30.160000         -0.033643         -0.047825
# 2024-12-27  330.000000  29.469999         -0.022878         -0.032400
# 2024-12-30  302.959991  27.480000         -0.067526         -0.081939
# ...

# %%
fig = go.Figure()

# Add MSTY trace
fig.add_trace(
    go.Scatter(x=MSTY.index, y=MSTY[('Close', 'MSTY')], name='MSTY', yaxis='y1')
)

# Add MSTR trace
fig.add_trace(
    go.Scatter(x=MSTY.index, y=MSTY[('Close', 'MSTR')], name='MSTR', yaxis='y2')
)

# Create axis objects
fig.update_layout(
    xaxis=dict(title='Date'),
    yaxis=dict(title='MSTY', side='left'),
    yaxis2=dict(title='MSTR', side='right', overlaying='y')
)

fig.show()

# %%
# Extract the closing prices for BITO
bito_closing_prices = btcy[('Close', 'BITO')].reset_index()

# Rename the columns for clarity
bito_closing_prices.columns = ['Date', 'Close']

# Display the DataFrame
bito_closing_prices.tail()

# Resample the DataFrame into months
bito_monthly = bito_closing_prices.resample('M', on='Date').last()

# Display the resampled DataFrame
bito_monthly.tail()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_20004\1781283923.py:11: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#                 Close
# Date
# 2024-08-31  19.000000
# 2024-09-30  19.190001
# 2024-10-31  19.879999
# 2024-11-30  26.139999
# 2024-12-31  22.780001

# %%
# Save the DataFrame to a CSV file in the Resources folder
combined_df_monthly.to_csv('Resources/bito.csv', index=False)
